# %%
! pip install transformers datasets torch sklearn
# Out:
# ...
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# ...
#   Using cached datasets-4.4.2-py3-none-any.whl.metadata (19 kB)
# ERROR: Could not find a version that satisfies the requirement torch (from versions: none)
# ERROR: No matching distribution found for torch

# %%
import pandas as pd
from datasets import Dataset

# URL du fichier CSV sur Hugging Face
csv_url = "https://huggingface.co/datasets/mrm8488/goemotions/blob/main/goemotions.csv"

# Charger le fichier CSV avec pandas
df = pd.read_csv(csv_url)

# Convertir le DataFrame pandas en un dataset Hugging Face
dataset = Dataset.from_pandas(df)

# Afficher un aperçu du dataset
print(dataset)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 import pandas as pd
#       2 from datasets import Dataset
#       4 # URL du fichier CSV sur Hugging Face
#
# ModuleNotFoundError: No module named 'pandas'
